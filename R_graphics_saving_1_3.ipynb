# %% [markdown]
# <a href="https://colab.research.google.com/github/nedokormysh/Stepik_R_graphics/blob/main/R_graphics_saving_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
library(ggplot2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
png("cars.png")
plot(cars)
dev.off()
# Out:
# png
#   2

# %% [markdown]
# # 1_3_4
#
# Что произойдёт, если не указать название файла при вызове функции svg() или png()?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ggplot(cars, aes(speed, dist)) + geom_point()

ggsave("cars_1.png")
# Out:
# Saving 6.67 x 6.67 in image
# plot without title

# %%
myggplot <- ggplot(cars, aes(speed, dist)) + geom_point()
ggsave("cars_2.png", myggplot)
# Out:
# Saving 6.67 x 6.67 in image

# %% [markdown]
# # 1_3_6
#
# Что произойдёт, если не указать название файла при вызове функции ggsave()?

# %%
ggsave()
# Out:
# Error in ggsave(): argument "filename" is missing, with no default
# Traceback:
#
# 1. ggsave()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1_3_7
#
# Изучите справку к функции png и укажите в ответе, на что нужно заменить arg1, arg2 и arg3, чтобы сохранить график размером 12x8 см. 12 — это ширина, 8 — высота.
#
# png("cars_base.png", arg1 = 12, arg2 = 8, arg3 = "cm")
#
# В ответе должны быть три слова, разделённые запятой и пробелом.

# %%
?png

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1_3_8
#
# Какой параметр нужно добавить, чтобы команда с предыдущего шага наконец сработала?
#
# Напишите только название аргумента (одно слово).

# %%
?png

# %%
png("cars_base.png", width = 12, height = 8, units = "cm", res = 200)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1_3_9
#
# Изучите справку к функции ggsave и укажите в ответе, на что нужно заменить arg1, arg2 и arg3, чтобы сохранить график размером 12x8 см. 12 — это ширина, 8 — высота.
#
# ggsave("test.png", arg1 = 12, arg2 = 8, arg3 = "px")
#
# В ответе должны быть три слова, разделённые запятой и пробелом.

# %%
?ggsave

# %%
# width, height, units

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 1_3_10
#
# Изучите справку к функции ggsave ещё внимательнее и найдите аргумент, аналогичный тому, который мы добавляли к функции png(). Напишите в ответ название этого аргумента и его значение по умолчанию через знак равно, окружённый пробелами.
#
# Пример ответа:
#
# arg = 555

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# dpi = 300
